# %% [markdown]
# # Ct value solver for Rotor-Gene Q
# #### This script computes Ct values by retrieving raw excel files that were generated by Rotor-Gene Q and then converting them to the pandas dataframe. The computed Ct values are saved in an excel file "output.xlsx".

# %%
import pandas as pd
import numpy as np
from scipy import interpolate
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/kkim/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# #### A Ct value is computed for a given value of threshold (thresh). If there is no solution for the Ct value, returns np.nan.

# %%
def find_ct(x, y, thresh):
    x = np.array(x)
    y = np.array(y)
    tck = interpolate.splrep(x, y, s=0)
    xnew = np.arange(x.min(), x.max(), (x.max()-x.min())/50.)
    ynew = interpolate.splev(xnew, tck, der=0)
    tck_thresh = interpolate.splrep(x,y-thresh)
    try:  
        return interpolate.sproot(tck_thresh)[0]
    except:
        return np.nan

# %% [markdown]
# #### If you want to exclude multiple wells, e.g. 25, 30, 33, and 40, you can use a list like [25, 30, 33, 40]. Even though you want to remove a single well, a list needs to be used like [25], not 25.

# %%
def generate_df(file_name, threshold, well_number_excluded=[]):
    
    table = pd.read_excel(file_name)
    max_sample_num = len(table.columns)/3
    table = table.rename(columns={'Text': 'Text.0', 'X':'X.0', 'Y':'Y.0'})
    for i in reversed(range(0,max_sample_num)):
        table = table.rename(columns = {('Text.'+str(i)):('Text.'+str(i+1)), 
                             ('X.'+str(i)):('X.'+str(i+1)), 
                             ('Y.'+str(i)):('Y.'+str(i+1))})

    for i in well_number_excluded:
        str1 = 'Text.'+str(i)
        str2 = 'X.'+str(i)
        str3 = 'Y.'+str(i)
        table = table.drop(str1, 1)
        table = table.drop(str2, 1)
        table = table.drop(str3, 1)
    xs = np.array(table.columns).reshape(-1, 3).T[1]
    ys = np.array(table.columns).reshape(-1, 3).T[2]
    # print xs, ys

    well_number_included = range(1, max_sample_num+1)
    well_number_included = [i for i in well_number_included if i not in well_number_excluded]

    wells = []
    samples = []
    for i in well_number_included:
        well, sample  = table['Text.' + str(i)][0].split(':')
        wells.append(well)
        samples.append(sample)
    
    cts = []
    threshold = 2
    for i in range(0,len(xs)):
        ct = find_ct(table[xs[i]], table[ys[i]], threshold)
        cts.append(ct)
    
    df_cts = pd.DataFrame()
    df_cts['ct'] = cts
    well_numbers = [xs[i].split('.')[1] for i in range(0, len(xs))]

    df_cts['well number'] = map(int, wells)
    df_cts['sample'] = samples
    df_cts['file_name'] = file_name 
    return df_cts

# %% [markdown]
# #### sample format: read the file "#2 amplification.xls" without excluding any wells, and then append to the current dataframe df.
# df = df.append(generate_df('data/#2 amplification.xls', []))
# #### When excluding 25 and 30 and 50.
# df = df.append(generate_df('data/#3 amplification.xls', [25, 30, 50]))

# %%
df = pd.DataFrame()
df = df.append(generate_df('data/#1 amplification.xls', threshold = 2))
df = df.append(generate_df('data/#2 amplification.xls', threshold = 2))
df = df.append(generate_df('data/#3 amplification.xls', threshold = 2))
df = df.append(generate_df('data/#4 amplification.xls', threshold = 2))
df = df.append(generate_df('data/#5 amplification.xls', threshold = 2))
df = df.append(generate_df('data/#6 amplification.xls', threshold = 2))
df = df.append(generate_df('data/#7 amplification.xls', threshold = 2))
df = df.append(generate_df('data/#8 amplification.xls', threshold = 2))

print df
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
#            ct  well number            sample                  file_name
# 0   22.366810            1    KK61_1_D01-A-A  data/#1 amplification.xls
# 1   22.874093            2    KK61_1_D01-A-A  data/#1 amplification.xls
# 2   22.595229            3    KK61_1_D01-A-A  data/#1 amplification.xls
# 3   21.947214            4    KK61_1_D01-A+A  data/#1 amplification.xls
# 4   21.839458            5    KK61_1_D01-A+A  data/#1 amplification.xls
# 5   21.900820            6    KK61_1_D01-A+A  data/#1 amplification.xls
# 6   22.023531            7    KK61_1_D01+A-A  data/#1 amplification.xls
# 7   22.736516            8    KK61_1_D01+A-A  data/#1 amplification.xls
# 8   22.176898            9    KK61_1_D01+A-A  data/#1 amplification.xls
# 9   22.413071           10    KK61_1_D01+A+A  data/#1 amplification.xls
# 10  22.386312           11    KK61_1_D01+A+A  data/#1 amplification.xls
# 11  22.949734           12    KK61_1_D01+A+A  data/#1 amplification.xls
# 12  21.809547           13    KK61_1_D10-A-A  data/#1 amplification.xls
# 13  22.313540           14    KK61_1_D10-A-A  data/#1 amplification.xls
# 14  21.891454           15    KK61_1_D10-A-A  data/#1 amplification.xls
# 15  22.069397           16    KK61_1_D10-A+A  data/#1 amplification.xls
# 16  21.280015           17   KK61_1_D101-A+A  data/#1 amplification.xls
# 17  21.575713           18    KK61_1_D10-A+A  data/#1 amplification.xls
# 18  21.844596           19    KK61_1_D10+A-A  data/#1 amplification.xls
# 19  22.244500           20    KK61_1_D10+A-A  data/#1 amplification.xls
# 20  21.086242           21    KK61_1_D10+A-A  data/#1 amplification.xls
# 21  22.002592           22    KK61_1_D10+A+A  data/#1 amplification.xls
# 22  21.534230           23    KK61_1_D10+A+A  data/#1 amplification.xls
# 23  22.367761           24    KK61_1_D10+A+A  data/#1 amplification.xls
# 24        NaN           25    KK61_1_D01-A-A  data/#1 amplification.xls
# 25  23.786259           26    KK61_1_D01-A-A  data/#1 amplification.xls
# 26  23.784545           27    KK61_1_D01-A-A  data/#1 amplification.xls
# 27  24.275173           28    KK61_1_D01-A+A  data/#1 amplification.xls
# 28  23.843013           29    KK61_1_D01-A+A  data/#1 amplification.xls
# 29  24.124485           30    KK61_1_D01-A+A  data/#1 amplification.xls
# ..        ...          ...               ...                        ...
# 42  26.926479           43   JYL02_3_D10+I-I  data/#8 amplification.xls
# 43  27.375028           44   JYL02_3_D10+I-I  data/#8 amplification.xls
# 44  26.570733           45   JYL02_3_D10+I-I  data/#8 amplification.xls
# 45  25.447835           46   JYL02_3_D10+I+I  data/#8 amplification.xls
# 46  25.085142           47   JYL02_3_D10+I+I  data/#8 amplification.xls
# 47  25.496526           48   JYL02_3_D10+I+I  data/#8 amplification.xls
# 48  22.303267           49   JYL02_3_D01-I-I  data/#8 amplification.xls
# 49  22.378805           50   JYL02_3_D01-I-I  data/#8 amplification.xls
# 50  22.098846           51   JYL02_3_D01-I-I  data/#8 amplification.xls
# 51  22.786481           52   JYL02_3_D01-I+I  data/#8 amplification.xls
# 52  22.273959           53   JYL02_3_D01-I+I  data/#8 amplification.xls
# 53  22.732151           54   JYL02_3_D01-I+I  data/#8 amplification.xls
# 54  23.277019           55   JYL02_3_D01+I-I  data/#8 amplification.xls
# 55  23.892269           56   JYL02_3_D01+I-I  data/#8 amplification.xls
# 56  22.902183           57   JYL02_3_D01+I-I  data/#8 amplification.xls
# 57  22.668848           58   JYL02_3_D01+I+I  data/#8 amplification.xls
# 58  22.599437           59   JYL02_3_D01+I+I  data/#8 amplification.xls
# 59  23.385703           60   JYL02_3_D01+I+I  data/#8 amplification.xls
# 60  22.331933           61   JYL02_3_D10-I-I  data/#8 amplification.xls
# 61  22.928281           62   JYL02_3_D10-I-I  data/#8 amplification.xls
# 62  22.640377           63   JYL02_3_D10-I-I  data/#8 amplification.xls
# 63  22.576351           64   JYL02_3_D10-I+I  data/#8 amplification.xls
# 64  21.933927           65   JYL02_3_D10-I+I  data/#8 amplification.xls
# 65  21.904545           66   JYL02_3_D10-I+I  data/#8 amplification.xls
# 66  26.733351           67   JYL02_3_D10+I-I  data/#8 amplification.xls
# 67  27.596033           68   JYL02_3_D10+I-I  data/#8 amplification.xls
# 68  26.944052           69   JYL02_3_D10+I-I  data/#8 amplification.xls
# 69  25.227013           70   JYL02_3_D10+I+I  data/#8 amplification.xls
# 70  25.104787           71   JYL02_3_D10+I+I  data/#8 amplification.xls
# 71  25.282940           72   JYL02_3_D10+I+I  data/#8 amplification.xls
#
# [528 rows x 4 columns]

# %% [markdown]
# #### The dataframe df is saved as an excel file

# %%
writer = pd.ExcelWriter('output.xlsx')
df.to_excel(writer,'Sheet1')
writer.save()
