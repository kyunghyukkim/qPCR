# %%
import pandas as pd
import numpy as np
from scipy import interpolate
import matplotlib.pyplot as plt
# %matplotlib inline

def find_ct(x, y, thresh):
    x = np.array(x)
    y = np.array(y)
    tck = interpolate.splrep(x, y, s=0)
    xnew = np.arange(x.min(), x.max(), (x.max()-x.min())/50.)
    ynew = interpolate.splev(xnew, tck, der=0)
    tck_thresh = interpolate.splrep(x,y-thresh)
    return interpolate.sproot(tck_thresh)[0]
# If you want to exclude multiple wells, e.g. 25, 30, 33, and 40, you can use a list like [25, 30, 33, 40].
# Even though you want to remove a single well, a list needs to be used like [25], not 25.

def generate_df(file_name, well_number_excluded):
    
    table = pd.read_excel(file_name)
    table = table.rename(columns={'Text': 'Text.0', 'X':'X.0', 'Y':'Y.0'})
    for i in reversed(range(0,72)):
        table = table.rename(columns = {('Text.'+str(i)):('Text.'+str(i+1)), 
                             ('X.'+str(i)):('X.'+str(i+1)), 
                             ('Y.'+str(i)):('Y.'+str(i+1))})

    for i in well_number_excluded:
        str1 = 'Text.'+str(i)
        str2 = 'X.'+str(i)
        str3 = 'Y.'+str(i)
        table = table.drop(str1, 1)
        table = table.drop(str2, 1)
        table = table.drop(str3, 1)
    xs = np.array(table.columns).reshape(-1, 3).T[1]
    ys = np.array(table.columns).reshape(-1, 3).T[2]
    # print xs, ys

    well_number_included = range(1, 73)
    well_number_included = [i for i in well_number_included if i not in well_number_excluded]

    wells = []
    samples = []
    for i in well_number_included:
        well, sample  = table['Text.' + str(i)][0].split(':')
        wells.append(well)
        samples.append(sample)
    
    cts = []
    threshold = 2
    for i in range(0,len(xs)):
        ct = find_ct(table[xs[i]], table[ys[i]], threshold)
        cts.append(ct)
    
    df_cts = pd.DataFrame()
    df_cts['ct'] = cts
    well_numbers = [xs[i].split('.')[1] for i in range(0, len(xs))]

    df_cts['well number'] = map(int, wells)
    df_cts['sample'] = samples
    df_cts['file_name'] = file_name 
    return df_cts
# Out:
# /Users/kkim/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
df = pd.DataFrame()
#sample format: read the file "#1 amplification.xls" with the well number 25 excluded.
df = generate_df('data/#1 amplification.xls', [25])
#sample format: read the file "#2 amplification.xls" without excluding any wells.
df = df.append(generate_df('data/#2 amplification.xls', []))
#excluding 25 and 30 and 50.
df = df.append(generate_df('data/#3 amplification.xls', [25, 30, 50]))

print df
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-fb156c0f0ede> in <module>()
#       3 df = generate_df('data/#1 amplification.xls', [25])
#       4 #sample format: read the file "#2 amplification.xls" without excluding any wells.
# ----> 5 df = df.append(generate_df('data/#1 amplification.xls', []))
#       6 #excluding 25 and 30 and 50.
#       7 df = df.append(generate_df('data/#3 amplification.xls', [25, 30, 50]))
#
# <ipython-input-1-26fbd737fae0> in generate_df(file_name, well_number_excluded)
#      49     threshold = 2
#      50     for i in range(0,len(xs)):
# ---> 51         ct = find_ct(table[xs[i]], table[ys[i]], threshold)
#      52         cts.append(ct)
#      53
#
# <ipython-input-1-26fbd737fae0> in find_ct(x, y, thresh)
#      12     ynew = interpolate.splev(xnew, tck, der=0)
#      13     tck_thresh = interpolate.splrep(x,y-thresh)
# ---> 14     return interpolate.sproot(tck_thresh)[0]
#      15 # If you want to exclude multiple wells, e.g. 25, 30, 33, and 40, you can use a list like [25, 30, 33, 40].
#      16 # Even though you want to remove a single well, a list needs to be used like [25], not 25.
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
df1.append(df1)
# Out:
#            ct  well number            sample                  file_name
# 0   22.366810            1    KK61_1_D01-A-A  data/#1 amplification.xls
# 1   22.874093            2    KK61_1_D01-A-A  data/#1 amplification.xls
# 2   22.595229            3    KK61_1_D01-A-A  data/#1 amplification.xls
# 3   21.947214            4    KK61_1_D01-A+A  data/#1 amplification.xls
# 4   21.839458            5    KK61_1_D01-A+A  data/#1 amplification.xls
# 5   21.900820            6    KK61_1_D01-A+A  data/#1 amplification.xls
# 6   22.023531            7    KK61_1_D01+A-A  data/#1 amplification.xls
# 7   22.736516            8    KK61_1_D01+A-A  data/#1 amplification.xls
# 8   22.176898            9    KK61_1_D01+A-A  data/#1 amplification.xls
# 9   22.413071           10    KK61_1_D01+A+A  data/#1 amplification.xls
# 10  22.386312           11    KK61_1_D01+A+A  data/#1 amplification.xls
# 11  22.949734           12    KK61_1_D01+A+A  data/#1 amplification.xls
# 12  21.809547           13    KK61_1_D10-A-A  data/#1 amplification.xls
# 13  22.313540           14    KK61_1_D10-A-A  data/#1 amplification.xls
# 14  21.891454           15    KK61_1_D10-A-A  data/#1 amplification.xls
# 15  22.069397           16    KK61_1_D10-A+A  data/#1 amplification.xls
# 16  21.280015           17   KK61_1_D101-A+A  data/#1 amplification.xls
# 17  21.575713           18    KK61_1_D10-A+A  data/#1 amplification.xls
# 18  21.844596           19    KK61_1_D10+A-A  data/#1 amplification.xls
# 19  22.244500           20    KK61_1_D10+A-A  data/#1 amplification.xls
# 20  21.086242           21    KK61_1_D10+A-A  data/#1 amplification.xls
# 21  22.002592           22    KK61_1_D10+A+A  data/#1 amplification.xls
# 22  21.534230           23    KK61_1_D10+A+A  data/#1 amplification.xls
# 23  22.367761           24    KK61_1_D10+A+A  data/#1 amplification.xls
# 24  23.786259           26    KK61_1_D01-A-A  data/#1 amplification.xls
# 25  23.784545           27    KK61_1_D01-A-A  data/#1 amplification.xls
# 26  24.275173           28    KK61_1_D01-A+A  data/#1 amplification.xls
# 27  23.843013           29    KK61_1_D01-A+A  data/#1 amplification.xls
# 28  24.124485           30    KK61_1_D01-A+A  data/#1 amplification.xls
# 29  22.366001           31    KK61_1_D01+A-A  data/#1 amplification.xls
# ..        ...          ...               ...                        ...
# 41  22.620159           43    KK61_1_D10+A-A  data/#1 amplification.xls
# 42  23.197888           44    KK61_1_D10+A-A  data/#1 amplification.xls
# 43  22.413805           45    KK61_1_D10+A-A  data/#1 amplification.xls
# 44  22.826280           46    KK61_1_D10+A+A  data/#1 amplification.xls
# 45  22.438812           47    KK61_1_D10+A+A  data/#1 amplification.xls
# 46  23.195286           48    KK61_1_D10+A+A  data/#1 amplification.xls
# 47  23.779869           49    KK61_1_D01-A-A  data/#1 amplification.xls
# 48  23.830266           50    KK61_1_D01-A-A  data/#1 amplification.xls
# 49  23.399070           51    KK61_1_D01-A-A  data/#1 amplification.xls
# 50  24.303174           52    KK61_1_D01-A+A  data/#1 amplification.xls
# 51  23.989535           53    KK61_1_D01-A+A  data/#1 amplification.xls
# 52  23.736253           54    KK61_1_D01-A+A  data/#1 amplification.xls
# 53  21.768343           55    KK61_1_D01+A-A  data/#1 amplification.xls
# 54  23.106323           56    KK61_1_D01+A-A  data/#1 amplification.xls
# 55  22.487814           57    KK61_1_D01+A-A  data/#1 amplification.xls
# 56  24.233583           58    KK61_1_D01+A+A  data/#1 amplification.xls
# 57  23.875279           59    KK61_1_D01+A+A  data/#1 amplification.xls
# 58  24.384782           60    KK61_1_D01+A+A  data/#1 amplification.xls
# 59  21.630553           61    KK61_1_D10-A-A  data/#1 amplification.xls
# 60  21.951359           62    KK61_1_D10-A-A  data/#1 amplification.xls
# 61  21.345651           63    KK61_1_D10-A-A  data/#1 amplification.xls
# 62  22.785349           64    KK61_1_D10-A+A  data/#1 amplification.xls
# 63  23.017529           65   KK61_1_D101-A+A  data/#1 amplification.xls
# 64  22.309720           66    KK61_1_D10-A+A  data/#1 amplification.xls
# 65  22.166456           67    KK61_1_D10+A-A  data/#1 amplification.xls
# 66  22.782497           68    KK61_1_D10+A-A  data/#1 amplification.xls
# 67  22.565282           69    KK61_1_D10+A-A  data/#1 amplification.xls
# 68  22.671876           70    KK61_1_D10+A+A  data/#1 amplification.xls
# 69  21.926679           71    KK61_1_D10+A+A  data/#1 amplification.xls
# 70  22.934666           72    KK61_1_D10+A+A  data/#1 amplification.xls
#
# [142 rows x 4 columns]

# %%
plt.plot(table['X.24'], table['Y.24'], 'o')

# %%
cts = []
threshold = 2
for i in range(0,len(xs)):
    ct = find_ct(table[xs[i]], table[ys[i]], threshold)
    cts.append(ct)
print cts
# Out:
# [22.366809994872359, 22.874092839598038, 22.59522864014372, 21.947214219893894, 21.839457744797858, 21.900819524777894, 22.023530834788037, 22.736516074707584, 22.176898171279738, 22.413070710211649, 22.386312399323607, 22.949733950159263, 21.809547232411681, 22.313540340735596, 21.891454278318051, 22.069396561743332, 21.280014672966871, 21.575713450517476, 21.84459561188061, 22.244500208422483, 21.086241769788899, 22.002591984433515, 21.534230421450616, 22.3677609823261, 23.786259338615903, 23.784545185582385, 24.275172750165375, 23.843012512394846, 24.124484852214611, 22.36600123675672, 23.160248520539991, 22.635555294778765, 24.204136361412189, 23.732329776783892, 24.648811645238869, 21.391412318975945, 21.88781302685592, 21.685029569316239, 22.640920589586194, 22.277358246873813, 22.584696840706009, 22.620159016125509, 23.197888470595615, 22.413805393492865, 22.826280435075656, 22.438811891263661, 23.195285677384334, 23.779868547584304, 23.830266291035461, 23.39907002796043, 24.303174223673341, 23.989535373921775, 23.736253131831372, 21.768342828877824, 23.106322545556544, 22.487813831384788, 24.233582603512293, 23.875279408574308, 24.384782172176003, 21.630552654260903, 21.951358525762362, 21.34565142223838, 22.785348571154096, 23.017529230488105, 22.309719821624281, 22.166455928124908, 22.782497224334104, 22.565282011491274, 22.671875647172261, 21.926678822863025, 22.934665567456967]

# %%
df_cts = pd.DataFrame()
df_cts['ct'] = cts
well_numbers = [xs[i].split('.')[1] for i in range(0, len(xs))]

df_cts['well number'] = map(int, wells)
df_cts['sample'] = samples

# %%
df_cts[df_cts['well number']==70]['sample']
# Out:
# 68     KK61_1_D10+A+A
# Name: sample, dtype: object

# %%
df_cts[df_cts['sample'] == 'KK61_1_D10+A+A']
# Out:
# Empty DataFrame
# Columns: [ct, well number, sample]
# Index: []

# %%
writer = pd.ExcelWriter('output.xlsx')
df1 = pd.DataFrame(cts)
df1.to_excel(writer,'Sheet1')
writer.save()
